# %%
import networkx as nx

G = nx.Graph()

ingredients = ["spaghetti", "cheese", "salt", "chicken", "lettuce", "tomato", "olive oil", "pepper", "rice", "onion", "chicken broth", "tortilla", "ground beef", "sauce", "eggs", "spinach", "garlic", "cucumber", "olives", "brocoli", "carrot", "bell peppers", "soja", "mayonnaise", "zucchini"]

"""for i in range(len(ingredients)):
    print(f"{ingredients[i]}: {i}") """

recipes = ["pasta", "chicken salad", "chicken w rice", "beef tacos", "spinach frittata", "tomato soup", "greek salad", "sauteed vegetables", "chicken wrap", "grilled chicken"]

recipes_conection = [[(ingredients[0], recipes[0]), (ingredients[1], recipes[0]), (ingredients[2], recipes[0])], [(ingredients[3], recipes[1]), (ingredients[4], recipes[1]), (ingredients[5], recipes[1]), (ingredients[6], recipes[1]), (ingredients[2], recipes[1]), (ingredients[7], recipes[1])],[(ingredients[8], recipes[2]), (ingredients[3], recipes[2]), (ingredients[9], recipes[2]), (ingredients[10], recipes[2]), (ingredients[2], recipes[2])], [(ingredients[11], recipes[3]), (ingredients[12], recipes[3]), (ingredients[9], recipes[3]), (ingredients[13], recipes[3]), (ingredients[2], recipes[3]), (ingredients[7], recipes[3])], [(ingredients[14], recipes[4]), (ingredients[15], recipes[4]), (ingredients[9], recipes[4]), (ingredients[6], recipes[4]), (ingredients[2], recipes[4]), (ingredients[7], recipes[4])], [(ingredients[5], recipes[5]), (ingredients[9], recipes[5]), (ingredients[10], recipes[5]), (ingredients[16], recipes[5]), (ingredients[6], recipes[5])], [(ingredients[17], recipes[6]), (ingredients[5], recipes[6]), (ingredients[1], recipes[6]), (ingredients[18], recipes[6]), (ingredients[6], recipes[6])], [(ingredients[19], recipes[7]), (ingredients[20], recipes[7]), (ingredients[21], recipes[7]), (ingredients[6], recipes[7]), (ingredients[22], recipes[7])], [(ingredients[11], recipes[8]), (ingredients[3], recipes[8]), (ingredients[4], recipes[8]), (ingredients[23], recipes[8]), (ingredients[2], recipes[8]), (ingredients[7], recipes[8])], [(ingredients[3], recipes[9]), (ingredients[24], recipes[9]), (ingredients[20], recipes[9]), (ingredients[6], recipes[9]), (ingredients[2], recipes[9]), (ingredients[7], recipes[9])]]

G.add_nodes_from(ingredients)
G.add_nodes_from(recipes)

for i in range(len(recipes_conection)): 
    G.add_edges_from(recipes_conection[i])

nx.draw(G, with_labels=True, node_color="red",node_size=3000, font_color="white")
